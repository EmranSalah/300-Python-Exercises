# %% [markdown]
# ### Setup the environment

# %%
python -m venv venv

# %% [markdown]
# #### Problem one:
# - Write a program to show such type of layout of numbers and squares
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Algorithm
# 1. Step 1: Print "Numbrer" & "Square" having two time tab
# 1. Step 2: Print "1" and Print multiplication of 1 by 1
# 1. Step 3: Print "2" and Print multiplication of 2 bby 2
# 1. Step 4: Print "3" and Print multiplication of 3 by 3
# 1. Step 5: Print "4" and Print multiplication of 4 by 4
# 1. Step 6: Print "5" and Print multiplication of 5 by 5
# End

# %%
print("Number \t\t Square")
print(f"1 \t\t {1 * 1}") 
print(f"2 \t\t {2 * 2}")
print(f"3 \t\t {3 * 3}")
print(f"4 \t\t {4 * 4}")
print(f"5 \t\t {5 * 5}")
# Out:
# Number 		 Square
# 1 		 1
# 2 		 4
# 3 		 9
# 4 		 16
# 5 		 25

# %% [markdown]
# ### Write a program to show such type fo layout of number, square and cube
# Excepted results:
#
# ![image.png](attachment:image.png)

# %%
print("Number \t\t Square \t\t Cube")
print(f"1 \t\t {1 * 1} \t\t {1 * 1 * 1} \t\t") 
print(f"2 \t\t {2 * 2} \t\t {2 * 2 * 2} \t\t")
print(f"3 \t\t {3 * 3} \t\t {3 * 3 * 3} \t\t")
print(f"4 \t\t {4 * 4} \t\t {4 * 4 * 4} \t\t")
print(f"5 \t\t {5 * 5} \t\t {5 * 5 * 5} \t\t")
# Out:
# Number 		 Square 		 Cube
# 1 		 1 		 1
# 2 		 4 		 8
# 3 		 9 		 27
# 4 		 16 		 64
# 5 		 25 		 125
